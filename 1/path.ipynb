# %%
import osmnx as ox
import networkx as nx
import json

# Load preprocessed house nodes
with open('./houseNodes.json', encoding='utf-8') as f:
    houseRawNodes=json.load(f)

# %%
form = int(houseRawNodes[0]['closest'])
to = int(houseRawNodes[10]['closest'])

# %%
G = ox.load_graphml('omsk.graphml')
route = nx.shortest_path(G, form, to)
ox.plot_graph_route(G, route, edge_linewidth=0.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-07116066f17c> in <module>
#       1 G = ox.load_graphml('omsk.graphml')
#       2 route = nx.shortest_path(G, form, to)
# ----> 3 ox.plot_graph_route(G, route, edge_linewidth="0.1")
#       4
#
# ~\anaconda3\envs\ox\lib\site-packages\osmnx\plot.py in plot_graph_route(G, route, bbox, fig_height, fig_width, margin, bgcolor, axis_off, show, save, close, file_format, filename, dpi, annotate, node_color, node_size, node_alpha, node_edgecolor, node_zorder, edge_color, edge_linewidth, edge_alpha, use_geom, origin_point, destination_point, route_color, route_linewidth, route_alpha, orig_dest_node_alpha, orig_dest_node_size, orig_dest_node_color, orig_dest_point_color)
#     583
#     584     # plot the graph but not the route
# --> 585     fig, ax = plot_graph(G, bbox=bbox, fig_height=fig_height, fig_width=fig_width,
# ...

# %%
G.nodes
# Out:
# NodeView((1234550787, 288473100, 288473104, 2953936913, 3793731605, 410910753, 288473124, 1403289639, 1152663594, 3461480492, 4120412206, 3056762927, 353845294, 1237008437, 210321469, 210321475, 3907633223, 210321480, 353845319, 210321482, 1223934028, 210321485, 6627590222, 1124761682, 2291368021, 1694195984, 2841116773, 1223934056, 1223934057, 1735508074, 410992752, 2470705594, 410992754, 410992757, 621772921, 1223934074, 1223934082, 2216247429, 2216247432, 1223934098, 1223934101, 1013022870, 6226493613, 411025582, 411025584, 1013022897, 411025586, 411025587, 411025589, 411025590, 411025592, 411025593, 766247103, 5121392832, 1090748615, 7369785549, 3562684622, 3907633359, 1237008591, 2210889937, 1223934158, 1223934164, 1223934165, 4450615511, 3907633383, 688488684, 1103200495, 410583284, 410583285, 5723996404, 5723996405, 2884714743, 807633146, 1887748353, 1013022979, 5636548698, 688488710, 4189290760, 688488715, 3907633423, 1103200539, 1088799694, 1056702758, 1488421160, 849314090,
# ...
